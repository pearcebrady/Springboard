# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nc_19 = pd.read_csv('C:/Users/Brady Pearce/Documents/Springboard/df_19.csv')
nc_18 = pd.read_csv('C:/Users/Brady Pearce/Documents/Springboard/df_18.csv')
nc_17 = pd.read_csv('C:/Users/Brady Pearce/Documents/Springboard/df_17.csv')
nc_16 = pd.read_csv('C:/Users/Brady Pearce/Documents/Springboard/df_16.csv')
nc_15 = pd.read_csv('C:/Users/Brady Pearce/Documents/Springboard/df_15.csv')
print(nc_19.head(), nc_18.head(), nc_17.head(), nc_16.head(), nc_15.head())
# Out:
#    Unnamed: 0        GEOID  tpop  pnhwhite19   pnhasn19   pnhblk19    phisp19  \
# 0           1  37183050300  3350   85.611940   2.238806   8.567164   1.671642
# 1           2  37067002701  6700   26.626866   0.000000  41.985075  31.000000
# 2           3  37119005518  5359   33.756298  15.525285  40.156746   8.154506
# 3           4  37051003309  6546   41.964559   5.545371  31.622365  12.496181
# 4           5  37183053723  3401   74.242870   3.910614   8.938548   9.761835
#
#    nhwhite  nhasn  nhblk  ...  tpopfml50to54  tpopfml55to59  tpopfml60to61  \
# 0     2868     75    287  ...             41             20             44
# 1     1784      0   2813  ...            226            221             36
# 2     1809    832   2152  ...            148            133             53
# 3     2747    363   2070  ...            199            191             62
# 4     2525    133    304  ...             91             76             93
#
# ...

# %%
nc_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 64 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     435 non-null    int64
#  1   GEOID          435 non-null    int64
#  2   tpop           435 non-null    int64
#  3   pnhwhite19     430 non-null    float64
#  4   pnhasn19       430 non-null    float64
#  5   pnhblk19       430 non-null    float64
#  6   phisp19        430 non-null    float64
#  7   nhwhite        435 non-null    int64
#  8   nhasn          435 non-null    int64
#  9   nhblk          435 non-null    int64
#  10  hisp           435 non-null    int64
#  11  medinc19       425 non-null    float64
#  12  rent19         422 non-null    float64
#  13  houseval19     418 non-null    float64
#  14  pcol19         430 non-null    float64
#  15  tpop2          435 non-null    int64
#  16  tpopml         435 non-null    int64
# ...

# %%
missing = pd.concat([nc_19.isnull().sum(), 100 * nc_19.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
# Out:
#               count         %
# Unnamed: 0        0  0.000000
# tpopml65to66      0  0.000000
# tpopml67to69      0  0.000000
# tpopml70to74      0  0.000000
# tpopml75to79      0  0.000000
# ...             ...       ...
# pnhasn19          5  1.149425
# pnhwhite19        5  1.149425
# medinc19         10  2.298851
# rent19           13  2.988506
# houseval19       17  3.908046
#
# [64 rows x 2 columns]

# %%
nc_19.columns
# Out:
# Index(['Unnamed: 0', 'GEOID', 'tpop', 'pnhwhite19', 'pnhasn19', 'pnhblk19',
#        'phisp19', 'nhwhite', 'nhasn', 'nhblk', 'hisp', 'medinc19', 'rent19',
#        'houseval19', 'pcol19', 'tpop2', 'tpopml', 'tpopmlt5', 'tpopml5to9',
#        'tpopml10to14', 'tpopml15to17', 'tpopml18to19', 'tpopml20', 'tpopml21',
#        'tpopml22to24', 'tpopml25to29', 'tpopml30to34', 'tpopml35to39',
#        'tpopml40to44', 'tpopml45to49', 'tpopml50to54', 'tpopml55to59',
#        'tpopml60to61', 'tpopml62to64', 'tpopml65to66', 'tpopml67to69',
#        'tpopml70to74', 'tpopml75to79', 'tpopml80to85', 'tpopmlgt85', 'tpopfml',
#        'tpopfmlt5', 'tpopfml5to9', 'tpopfml10to14', 'tpopfml15to17',
#        'tpopfml18to19', 'tpopfml20', 'tpopfml21', 'tpopfml22to24',
#        'tpopfml25to29', 'tpopfml30to34', 'tpopfml35to39', 'tpopfml40to44',
#        'tpopfml45to49', 'tpopfml50to54', 'tpopfml55to59', 'tpopfml60to61',
#        'tpopfml62to64', 'tpopfml65to66', 'tpopfml67to69', 'tpopfml70to74',
# ...

# %%
nc_19['Percent of Total Population Male'] = nc_19['tpopml']/nc_19['tpop2']
nc_19['Percent of Male Population Under 5'] = nc_19['tpopmlt5']/nc_19['tpopml']
nc_19['Percent of Male Population 5 to 9'] = nc_19['tpopml5to9']/nc_19['tpopml']
nc_19['Percent of Male Population 10 to 14'] = nc_19['tpopml10to14']/nc_19['tpopml']
nc_19['Percent of Male Population 15 to 17'] = nc_19['tpopml15to17']/nc_19['tpopml']
nc_19['Percent of Male Population 18 to 19'] = nc_19['tpopml18to19']/nc_19['tpopml']
nc_19['Percent of Male Population 20'] = nc_19['tpopml20']/nc_19['tpopml']
nc_19['Percent of Male Population 21'] = nc_19['tpopml21']/nc_19['tpopml']
nc_19['Percent of Male Population 25 to 29'] = nc_19['tpopml25to29']/nc_19['tpopml']
nc_19['Percent of Male Population 30 to 34'] = nc_19['tpopml30to34']/nc_19['tpopml']
nc_19['Percent of Male Population 35 to 39'] = nc_19['tpopml35to39']/nc_19['tpopml']
nc_19['Percent of Male Population 40 to 44'] = nc_19['tpopml40to44']/nc_19['tpopml']
nc_19['Percent of Male Population 45 to 49'] = nc_19['tpopml45to49']/nc_19['tpopml']
nc_19['Percent of Male Population 50 to 54'] = nc_19['tpopml50to54']/nc_19['tpopml']
nc_19['Percent of Male Population 55 to 59'] = nc_19['tpopml55to59']/nc_19['tpopml']
nc_19['Percent of Male Population 60 to 61'] = nc_19['tpopml60to61']/nc_19['tpopml']
nc_19['Percent of Male Population 62 to 64'] = nc_19['tpopml62to64']/nc_19['tpopml']
nc_19['Percent of Male Population 65 to 66'] = nc_19['tpopml65to66']/nc_19['tpopml']
nc_19['Percent of Male Population 67 to 69'] = nc_19['tpopml67to69']/nc_19['tpopml']
nc_19['Percent of Male Population 70 to 74'] = nc_19['tpopml70to74']/nc_19['tpopml']
nc_19['Percent of Male Population 75 to 79'] = nc_19['tpopml75to79']/nc_19['tpopml']
nc_19['Percent of Male Population 80 to 85'] = nc_19['tpopml80to85']/nc_19['tpopml']
nc_19['Percent of Male Population Over 85'] = nc_19['tpopmlgt85']/nc_19['tpopml']

# %%
nc_19['Percent of Total Population Female'] = nc_19['tpopfml']/nc_19['tpop2']
nc_19['Percent of Female Population Under 5'] = nc_19['tpopfmlt5']/nc_19['tpopfml']
nc_19['Percent of Female Population 5 to 9'] = nc_19['tpopfml5to9']/nc_19['tpopfml']
nc_19['Percent of Female Population 10 to 14'] = nc_19['tpopfml10to14']/nc_19['tpopfml']
nc_19['Percent of Female Population 15 to 17'] = nc_19['tpopfml15to17']/nc_19['tpopfml']
nc_19['Percent of Female Population 18 to 19'] = nc_19['tpopfml18to19']/nc_19['tpopfml']
nc_19['Percent of Female Population 20'] = nc_19['tpopfml20']/nc_19['tpopfml']
nc_19['Percent of Female Population 21'] = nc_19['tpopfml21']/nc_19['tpopfml']
nc_19['Percent of Female Population 25 to 29'] = nc_19['tpopfml25to29']/nc_19['tpopfml']
nc_19['Percent of Female Population 30 to 34'] = nc_19['tpopfml30to34']/nc_19['tpopfml']
nc_19['Percent of Female Population 35 to 39'] = nc_19['tpopfml35to39']/nc_19['tpopfml']
nc_19['Percent of Female Population 40 to 44'] = nc_19['tpopfml40to44']/nc_19['tpopfml']
nc_19['Percent of Female Population 45 to 49'] = nc_19['tpopfml45to49']/nc_19['tpopfml']
nc_19['Percent of Female Population 50 to 54'] = nc_19['tpopfml50to54']/nc_19['tpopfml']
nc_19['Percent of Female Population 55 to 59'] = nc_19['tpopfml55to59']/nc_19['tpopfml']
nc_19['Percent of Female Population 60 to 61'] = nc_19['tpopfml60to61']/nc_19['tpopfml']
nc_19['Percent of Female Population 62 to 64'] = nc_19['tpopfml62to64']/nc_19['tpopfml']
nc_19['Percent of Female Population 65 to 66'] = nc_19['tpopfml65to66']/nc_19['tpopfml']
nc_19['Percent of Female Population 67 to 69'] = nc_19['tpopfml67to69']/nc_19['tpopfml']
nc_19['Percent of Female Population 70 to 74'] = nc_19['tpopfml70to74']/nc_19['tpopfml']
nc_19['Percent of Female Population 75 to 79'] = nc_19['tpopfml75to79']/nc_19['tpopfml']
nc_19['Percent of Female Population 80 to 85'] = nc_19['tpopfml80to85']/nc_19['tpopfml']
nc_19['Percent of Female Population Over 85'] = nc_19['tpopfmlgt85']/nc_19['tpopfml']
nc_19['Year'] = 2019

# %%
nc_18['Percent of Total Population Male'] = nc_18['tpopml']/nc_18['tpop2']
nc_18['Percent of Male Population Under 5'] = nc_18['tpopmlt5']/nc_18['tpopml']
nc_18['Percent of Male Population 5 to 9'] = nc_18['tpopml5to9']/nc_18['tpopml']
nc_18['Percent of Male Population 10 to 14'] = nc_18['tpopml10to14']/nc_18['tpopml']
nc_18['Percent of Male Population 15 to 17'] = nc_18['tpopml15to17']/nc_18['tpopml']
nc_18['Percent of Male Population 18 to 19'] = nc_18['tpopml18to19']/nc_18['tpopml']
nc_18['Percent of Male Population 20'] = nc_18['tpopml20']/nc_18['tpopml']
nc_18['Percent of Male Population 21'] = nc_18['tpopml21']/nc_18['tpopml']
nc_18['Percent of Male Population 25 to 29'] = nc_18['tpopml25to29']/nc_18['tpopml']
nc_18['Percent of Male Population 30 to 34'] = nc_18['tpopml30to34']/nc_18['tpopml']
nc_18['Percent of Male Population 35 to 39'] = nc_18['tpopml35to39']/nc_18['tpopml']
nc_18['Percent of Male Population 40 to 44'] = nc_18['tpopml40to44']/nc_18['tpopml']
nc_18['Percent of Male Population 45 to 49'] = nc_18['tpopml45to49']/nc_18['tpopml']
nc_18['Percent of Male Population 50 to 54'] = nc_18['tpopml50to54']/nc_18['tpopml']
nc_18['Percent of Male Population 55 to 59'] = nc_18['tpopml55to59']/nc_18['tpopml']
nc_18['Percent of Male Population 60 to 61'] = nc_18['tpopml60to61']/nc_18['tpopml']
nc_18['Percent of Male Population 62 to 64'] = nc_18['tpopml62to64']/nc_18['tpopml']
nc_18['Percent of Male Population 65 to 66'] = nc_18['tpopml65to66']/nc_18['tpopml']
nc_18['Percent of Male Population 67 to 69'] = nc_18['tpopml67to69']/nc_18['tpopml']
nc_18['Percent of Male Population 70 to 74'] = nc_18['tpopml70to74']/nc_18['tpopml']
nc_18['Percent of Male Population 75 to 79'] = nc_18['tpopml75to79']/nc_18['tpopml']
nc_18['Percent of Male Population 80 to 85'] = nc_18['tpopml80to85']/nc_18['tpopml']
nc_18['Percent of Male Population Over 85'] = nc_18['tpopmlgt85']/nc_18['tpopml']

# %%
nc_18['Percent of Total Population Female'] = nc_18['tpopfml']/nc_18['tpop2']
nc_18['Percent of Female Population Under 5'] = nc_18['tpopfmlt5']/nc_18['tpopfml']
nc_18['Percent of Female Population 5 to 9'] = nc_18['tpopfml5to9']/nc_18['tpopfml']
nc_18['Percent of Female Population 10 to 14'] = nc_18['tpopfml10to14']/nc_18['tpopfml']
nc_18['Percent of Female Population 15 to 17'] = nc_18['tpopfml15to17']/nc_18['tpopfml']
nc_18['Percent of Female Population 18 to 19'] = nc_18['tpopfml18to19']/nc_18['tpopfml']
nc_18['Percent of Female Population 20'] = nc_18['tpopfml20']/nc_18['tpopfml']
nc_18['Percent of Female Population 21'] = nc_18['tpopfml21']/nc_18['tpopfml']
nc_18['Percent of Female Population 25 to 29'] = nc_18['tpopfml25to29']/nc_18['tpopfml']
nc_18['Percent of Female Population 30 to 34'] = nc_18['tpopfml30to34']/nc_18['tpopfml']
nc_18['Percent of Female Population 35 to 39'] = nc_18['tpopfml35to39']/nc_18['tpopfml']
nc_18['Percent of Female Population 40 to 44'] = nc_18['tpopfml40to44']/nc_18['tpopfml']
nc_18['Percent of Female Population 45 to 49'] = nc_18['tpopfml45to49']/nc_18['tpopfml']
nc_18['Percent of Female Population 50 to 54'] = nc_18['tpopfml50to54']/nc_18['tpopfml']
nc_18['Percent of Female Population 55 to 59'] = nc_18['tpopfml55to59']/nc_18['tpopfml']
nc_18['Percent of Female Population 60 to 61'] = nc_18['tpopfml60to61']/nc_18['tpopfml']
nc_18['Percent of Female Population 62 to 64'] = nc_18['tpopfml62to64']/nc_18['tpopfml']
nc_18['Percent of Female Population 65 to 66'] = nc_18['tpopfml65to66']/nc_18['tpopfml']
nc_18['Percent of Female Population 67 to 69'] = nc_18['tpopfml67to69']/nc_18['tpopfml']
nc_18['Percent of Female Population 70 to 74'] = nc_18['tpopfml70to74']/nc_18['tpopfml']
nc_18['Percent of Female Population 75 to 79'] = nc_18['tpopfml75to79']/nc_18['tpopfml']
nc_18['Percent of Female Population 80 to 85'] = nc_18['tpopfml80to85']/nc_18['tpopfml']
nc_18['Percent of Female Population Over 85'] = nc_18['tpopfmlgt85']/nc_18['tpopfml']
nc_18['Year'] = 2018

# %%
nc_17['Percent of Total Population Male'] = nc_17['tpopml']/nc_17['tpop2']
nc_17['Percent of Male Population Under 5'] = nc_17['tpopmlt5']/nc_17['tpopml']
nc_17['Percent of Male Population 5 to 9'] = nc_17['tpopml5to9']/nc_17['tpopml']
nc_17['Percent of Male Population 10 to 14'] = nc_17['tpopml10to14']/nc_17['tpopml']
nc_17['Percent of Male Population 15 to 17'] = nc_17['tpopml15to17']/nc_17['tpopml']
nc_17['Percent of Male Population 18 to 19'] = nc_17['tpopml18to19']/nc_17['tpopml']
nc_17['Percent of Male Population 20'] = nc_17['tpopml20']/nc_17['tpopml']
nc_17['Percent of Male Population 21'] = nc_17['tpopml21']/nc_17['tpopml']
nc_17['Percent of Male Population 25 to 29'] = nc_17['tpopml25to29']/nc_17['tpopml']
nc_17['Percent of Male Population 30 to 34'] = nc_17['tpopml30to34']/nc_17['tpopml']
nc_17['Percent of Male Population 35 to 39'] = nc_17['tpopml35to39']/nc_17['tpopml']
nc_17['Percent of Male Population 40 to 44'] = nc_17['tpopml40to44']/nc_17['tpopml']
nc_17['Percent of Male Population 45 to 49'] = nc_17['tpopml45to49']/nc_17['tpopml']
nc_17['Percent of Male Population 50 to 54'] = nc_17['tpopml50to54']/nc_17['tpopml']
nc_17['Percent of Male Population 55 to 59'] = nc_17['tpopml55to59']/nc_17['tpopml']
nc_17['Percent of Male Population 60 to 61'] = nc_17['tpopml60to61']/nc_17['tpopml']
nc_17['Percent of Male Population 62 to 64'] = nc_17['tpopml62to64']/nc_17['tpopml']
nc_17['Percent of Male Population 65 to 66'] = nc_17['tpopml65to66']/nc_17['tpopml']
nc_17['Percent of Male Population 67 to 69'] = nc_17['tpopml67to69']/nc_17['tpopml']
nc_17['Percent of Male Population 70 to 74'] = nc_17['tpopml70to74']/nc_17['tpopml']
nc_17['Percent of Male Population 75 to 79'] = nc_17['tpopml75to79']/nc_17['tpopml']
nc_17['Percent of Male Population 80 to 85'] = nc_17['tpopml80to85']/nc_17['tpopml']
nc_17['Percent of Male Population Over 85'] = nc_17['tpopmlgt85']/nc_17['tpopml']

# %%
nc_17['Percent of Total Population Female'] = nc_17['tpopfml']/nc_17['tpop2']
nc_17['Percent of Female Population Under 5'] = nc_17['tpopfmlt5']/nc_17['tpopfml']
nc_17['Percent of Female Population 5 to 9'] = nc_17['tpopfml5to9']/nc_17['tpopfml']
nc_17['Percent of Female Population 10 to 14'] = nc_17['tpopfml10to14']/nc_17['tpopfml']
nc_17['Percent of Female Population 15 to 17'] = nc_17['tpopfml15to17']/nc_17['tpopfml']
nc_17['Percent of Female Population 18 to 19'] = nc_17['tpopfml18to19']/nc_17['tpopfml']
nc_17['Percent of Female Population 20'] = nc_17['tpopfml20']/nc_17['tpopfml']
nc_17['Percent of Female Population 21'] = nc_17['tpopfml21']/nc_17['tpopfml']
nc_17['Percent of Female Population 25 to 29'] = nc_17['tpopfml25to29']/nc_17['tpopfml']
nc_17['Percent of Female Population 30 to 34'] = nc_17['tpopfml30to34']/nc_17['tpopfml']
nc_17['Percent of Female Population 35 to 39'] = nc_17['tpopfml35to39']/nc_17['tpopfml']
nc_17['Percent of Female Population 40 to 44'] = nc_17['tpopfml40to44']/nc_17['tpopfml']
nc_17['Percent of Female Population 45 to 49'] = nc_17['tpopfml45to49']/nc_17['tpopfml']
nc_17['Percent of Female Population 50 to 54'] = nc_17['tpopfml50to54']/nc_17['tpopfml']
nc_17['Percent of Female Population 55 to 59'] = nc_17['tpopfml55to59']/nc_17['tpopfml']
nc_17['Percent of Female Population 60 to 61'] = nc_17['tpopfml60to61']/nc_17['tpopfml']
nc_17['Percent of Female Population 62 to 64'] = nc_17['tpopfml62to64']/nc_17['tpopfml']
nc_17['Percent of Female Population 65 to 66'] = nc_17['tpopfml65to66']/nc_17['tpopfml']
nc_17['Percent of Female Population 67 to 69'] = nc_17['tpopfml67to69']/nc_17['tpopfml']
nc_17['Percent of Female Population 70 to 74'] = nc_17['tpopfml70to74']/nc_17['tpopfml']
nc_17['Percent of Female Population 75 to 79'] = nc_17['tpopfml75to79']/nc_17['tpopfml']
nc_17['Percent of Female Population 80 to 85'] = nc_17['tpopfml80to85']/nc_17['tpopfml']
nc_17['Percent of Female Population Over 85'] = nc_17['tpopfmlgt85']/nc_17['tpopfml']
nc_17['Year'] = 2017

# %%
nc_16['Percent of Total Population Male'] = nc_16['tpopml']/nc_16['tpop2']
nc_16['Percent of Male Population Under 5'] = nc_16['tpopmlt5']/nc_16['tpopml']
nc_16['Percent of Male Population 5 to 9'] = nc_16['tpopml5to9']/nc_16['tpopml']
nc_16['Percent of Male Population 10 to 14'] = nc_16['tpopml10to14']/nc_16['tpopml']
nc_16['Percent of Male Population 15 to 17'] = nc_16['tpopml15to17']/nc_16['tpopml']
nc_16['Percent of Male Population 18 to 19'] = nc_16['tpopml18to19']/nc_16['tpopml']
nc_16['Percent of Male Population 20'] = nc_16['tpopml20']/nc_16['tpopml']
nc_16['Percent of Male Population 21'] = nc_16['tpopml21']/nc_16['tpopml']
nc_16['Percent of Male Population 25 to 29'] = nc_16['tpopml25to29']/nc_16['tpopml']
nc_16['Percent of Male Population 30 to 34'] = nc_16['tpopml30to34']/nc_16['tpopml']
nc_16['Percent of Male Population 35 to 39'] = nc_16['tpopml35to39']/nc_16['tpopml']
nc_16['Percent of Male Population 40 to 44'] = nc_16['tpopml40to44']/nc_16['tpopml']
nc_16['Percent of Male Population 45 to 49'] = nc_16['tpopml45to49']/nc_16['tpopml']
nc_16['Percent of Male Population 50 to 54'] = nc_16['tpopml50to54']/nc_16['tpopml']
nc_16['Percent of Male Population 55 to 59'] = nc_16['tpopml55to59']/nc_16['tpopml']
nc_16['Percent of Male Population 60 to 61'] = nc_16['tpopml60to61']/nc_16['tpopml']
nc_16['Percent of Male Population 62 to 64'] = nc_16['tpopml62to64']/nc_16['tpopml']
nc_16['Percent of Male Population 65 to 66'] = nc_16['tpopml65to66']/nc_16['tpopml']
nc_16['Percent of Male Population 67 to 69'] = nc_16['tpopml67to69']/nc_16['tpopml']
nc_16['Percent of Male Population 70 to 74'] = nc_16['tpopml70to74']/nc_16['tpopml']
nc_16['Percent of Male Population 75 to 79'] = nc_16['tpopml75to79']/nc_16['tpopml']
nc_16['Percent of Male Population 80 to 85'] = nc_16['tpopml80to85']/nc_16['tpopml']
nc_16['Percent of Male Population Over 85'] = nc_16['tpopmlgt85']/nc_16['tpopml']

# %%
nc_16['Percent of Total Population Female'] = nc_16['tpopfml']/nc_16['tpop2']
nc_16['Percent of Female Population Under 5'] = nc_16['tpopfmlt5']/nc_16['tpopfml']
nc_16['Percent of Female Population 5 to 9'] = nc_16['tpopfml5to9']/nc_16['tpopfml']
nc_16['Percent of Female Population 10 to 14'] = nc_16['tpopfml10to14']/nc_16['tpopfml']
nc_16['Percent of Female Population 15 to 17'] = nc_16['tpopfml15to17']/nc_16['tpopfml']
nc_16['Percent of Female Population 18 to 19'] = nc_16['tpopfml18to19']/nc_16['tpopfml']
nc_16['Percent of Female Population 20'] = nc_16['tpopfml20']/nc_16['tpopfml']
nc_16['Percent of Female Population 21'] = nc_16['tpopfml21']/nc_16['tpopfml']
nc_16['Percent of Female Population 25 to 29'] = nc_16['tpopfml25to29']/nc_16['tpopfml']
nc_16['Percent of Female Population 30 to 34'] = nc_16['tpopfml30to34']/nc_16['tpopfml']
nc_16['Percent of Female Population 35 to 39'] = nc_16['tpopfml35to39']/nc_16['tpopfml']
nc_16['Percent of Female Population 40 to 44'] = nc_16['tpopfml40to44']/nc_16['tpopfml']
nc_16['Percent of Female Population 45 to 49'] = nc_16['tpopfml45to49']/nc_16['tpopfml']
nc_16['Percent of Female Population 50 to 54'] = nc_16['tpopfml50to54']/nc_16['tpopfml']
nc_16['Percent of Female Population 55 to 59'] = nc_16['tpopfml55to59']/nc_16['tpopfml']
nc_16['Percent of Female Population 60 to 61'] = nc_16['tpopfml60to61']/nc_16['tpopfml']
nc_16['Percent of Female Population 62 to 64'] = nc_16['tpopfml62to64']/nc_16['tpopfml']
nc_16['Percent of Female Population 65 to 66'] = nc_16['tpopfml65to66']/nc_16['tpopfml']
nc_16['Percent of Female Population 67 to 69'] = nc_16['tpopfml67to69']/nc_16['tpopfml']
nc_16['Percent of Female Population 70 to 74'] = nc_16['tpopfml70to74']/nc_16['tpopfml']
nc_16['Percent of Female Population 75 to 79'] = nc_16['tpopfml75to79']/nc_16['tpopfml']
nc_16['Percent of Female Population 80 to 85'] = nc_16['tpopfml80to85']/nc_16['tpopfml']
nc_16['Percent of Female Population Over 85'] = nc_16['tpopfmlgt85']/nc_16['tpopfml']
nc_16['Year'] = 2016

# %%
nc_15['Percent of Total Population Male'] = nc_15['tpopml']/nc_15['tpop2']
nc_15['Percent of Male Population Under 5'] = nc_15['tpopmlt5']/nc_15['tpopml']
nc_15['Percent of Male Population 5 to 9'] = nc_15['tpopml5to9']/nc_15['tpopml']
nc_15['Percent of Male Population 10 to 14'] = nc_15['tpopml10to14']/nc_15['tpopml']
nc_15['Percent of Male Population 15 to 17'] = nc_15['tpopml15to17']/nc_15['tpopml']
nc_15['Percent of Male Population 18 to 19'] = nc_15['tpopml18to19']/nc_15['tpopml']
nc_15['Percent of Male Population 20'] = nc_15['tpopml20']/nc_15['tpopml']
nc_15['Percent of Male Population 21'] = nc_15['tpopml21']/nc_15['tpopml']
nc_15['Percent of Male Population 25 to 29'] = nc_15['tpopml25to29']/nc_15['tpopml']
nc_15['Percent of Male Population 30 to 34'] = nc_15['tpopml30to34']/nc_15['tpopml']
nc_15['Percent of Male Population 35 to 39'] = nc_15['tpopml35to39']/nc_15['tpopml']
nc_15['Percent of Male Population 40 to 44'] = nc_15['tpopml40to44']/nc_15['tpopml']
nc_15['Percent of Male Population 45 to 49'] = nc_15['tpopml45to49']/nc_15['tpopml']
nc_15['Percent of Male Population 50 to 54'] = nc_15['tpopml50to54']/nc_15['tpopml']
nc_15['Percent of Male Population 55 to 59'] = nc_15['tpopml55to59']/nc_15['tpopml']
nc_15['Percent of Male Population 60 to 61'] = nc_15['tpopml60to61']/nc_15['tpopml']
nc_15['Percent of Male Population 62 to 64'] = nc_15['tpopml62to64']/nc_15['tpopml']
nc_15['Percent of Male Population 65 to 66'] = nc_15['tpopml65to66']/nc_15['tpopml']
nc_15['Percent of Male Population 67 to 69'] = nc_15['tpopml67to69']/nc_15['tpopml']
nc_15['Percent of Male Population 70 to 74'] = nc_15['tpopml70to74']/nc_15['tpopml']
nc_15['Percent of Male Population 75 to 79'] = nc_15['tpopml75to79']/nc_15['tpopml']
nc_15['Percent of Male Population 80 to 85'] = nc_15['tpopml80to85']/nc_15['tpopml']
nc_15['Percent of Male Population Over 85'] = nc_15['tpopmlgt85']/nc_15['tpopml']

# %%
nc_15['Percent of Total Population Female'] = nc_15['tpopfml']/nc_15['tpop2']
nc_15['Percent of Female Population Under 5'] = nc_15['tpopfmlt5']/nc_15['tpopfml']
nc_15['Percent of Female Population 5 to 9'] = nc_15['tpopfml5to9']/nc_15['tpopfml']
nc_15['Percent of Female Population 10 to 14'] = nc_15['tpopfml10to14']/nc_15['tpopfml']
nc_15['Percent of Female Population 15 to 17'] = nc_15['tpopfml15to17']/nc_15['tpopfml']
nc_15['Percent of Female Population 18 to 19'] = nc_15['tpopfml18to19']/nc_15['tpopfml']
nc_15['Percent of Female Population 20'] = nc_15['tpopfml20']/nc_15['tpopfml']
nc_15['Percent of Female Population 21'] = nc_15['tpopfml21']/nc_15['tpopfml']
nc_15['Percent of Female Population 25 to 29'] = nc_15['tpopfml25to29']/nc_15['tpopfml']
nc_15['Percent of Female Population 30 to 34'] = nc_15['tpopfml30to34']/nc_15['tpopfml']
nc_15['Percent of Female Population 35 to 39'] = nc_15['tpopfml35to39']/nc_15['tpopfml']
nc_15['Percent of Female Population 40 to 44'] = nc_15['tpopfml40to44']/nc_15['tpopfml']
nc_15['Percent of Female Population 45 to 49'] = nc_15['tpopfml45to49']/nc_15['tpopfml']
nc_15['Percent of Female Population 50 to 54'] = nc_15['tpopfml50to54']/nc_15['tpopfml']
nc_15['Percent of Female Population 55 to 59'] = nc_15['tpopfml55to59']/nc_15['tpopfml']
nc_15['Percent of Female Population 60 to 61'] = nc_15['tpopfml60to61']/nc_15['tpopfml']
nc_15['Percent of Female Population 62 to 64'] = nc_15['tpopfml62to64']/nc_15['tpopfml']
nc_15['Percent of Female Population 65 to 66'] = nc_15['tpopfml65to66']/nc_15['tpopfml']
nc_15['Percent of Female Population 67 to 69'] = nc_15['tpopfml67to69']/nc_15['tpopfml']
nc_15['Percent of Female Population 70 to 74'] = nc_15['tpopfml70to74']/nc_15['tpopfml']
nc_15['Percent of Female Population 75 to 79'] = nc_15['tpopfml75to79']/nc_15['tpopfml']
nc_15['Percent of Female Population 80 to 85'] = nc_15['tpopfml80to85']/nc_15['tpopfml']
nc_15['Percent of Female Population Over 85'] = nc_15['tpopfmlgt85']/nc_15['tpopfml']
nc_15['Year'] = 2015

# %%
x = [nc_15[nc_15['GEOID'] == 37067002001]['Percent of Total Population Male'], nc_16[nc_16['GEOID'] == 37067002001]['Percent of Total Population Male'], nc_17[nc_17['GEOID'] == 37067002001]['Percent of Total Population Male'], nc_18[nc_18['GEOID'] == 37067002001]['Percent of Total Population Male'], nc_19[nc_19['GEOID'] == 37067002001]['Percent of Total Population Male']]
y = [2015, 2016, 2017, 2018, 2019]

plt.scatter(y, x)

# %%
x = [nc_15[nc_15['GEOID'] == 37067002001]['houseval15'], nc_16[nc_16['GEOID'] == 37067002001]['houseval16'], nc_17[nc_17['GEOID'] == 37067002001]['houseval17'], nc_18[nc_18['GEOID'] == 37067002001]['houseval18'], nc_19[nc_19['GEOID'] == 37067002001]['houseval19']]
y = [2015, 2016, 2017, 2018, 2019]

plt.scatter(y, x)

# %%
nc_19.rename(columns={'pnhwhite19':'pnhwhite', 'pnhasn19':'pnhasn', 'pnhblk19':'pnhblk', 'phisp19':'phisp', 'medinc19':'medinc', 'rent19':'rent', 
                     'houseval19':'houseval', 'pcol19':'pcol'}, inplace=True)
nc_19.columns
# Out:
# Index(['Unnamed: 0', 'GEOID', 'tpop', 'pnhwhite', 'pnhasn', 'pnhblk', 'phisp',
#        'nhwhite', 'nhasn', 'nhblk',
#        ...
#        'Percent of Female Population 55 to 59',
#        'Percent of Female Population 60 to 61',
#        'Percent of Female Population 62 to 64',
#        'Percent of Female Population 65 to 66',
#        'Percent of Female Population 67 to 69',
#        'Percent of Female Population 70 to 74',
#        'Percent of Female Population 75 to 79',
#        'Percent of Female Population 80 to 85',
#        'Percent of Female Population Over 85', 'Year'],
#       dtype='object', length=111)

# %%
nc_18.rename(columns={'pnhwhite18':'pnhwhite', 'pnhasn18':'pnhasn', 'pnhblk18':'pnhblk', 'phisp18':'phisp', 'medinc18':'medinc', 'rent18':'rent', 
                     'houseval18':'houseval', 'pcol18':'pcol'}, inplace=True)
nc_18.columns
# Out:
# Index(['Unnamed: 0', 'GEOID', 'tpop', 'pnhwhite', 'pnhasn', 'pnhblk', 'phisp',
#        'nhwhite', 'nhasn', 'nhblk',
#        ...
#        'Percent of Female Population 55 to 59',
#        'Percent of Female Population 60 to 61',
#        'Percent of Female Population 62 to 64',
#        'Percent of Female Population 65 to 66',
#        'Percent of Female Population 67 to 69',
#        'Percent of Female Population 70 to 74',
#        'Percent of Female Population 75 to 79',
#        'Percent of Female Population 80 to 85',
#        'Percent of Female Population Over 85', 'Year'],
#       dtype='object', length=111)

# %%
nc_17.rename(columns={'pnhwhite17':'pnhwhite', 'pnhasn17':'pnhasn', 'pnhblk17':'pnhblk', 'phisp17':'phisp', 'medinc17':'medinc', 'rent17':'rent', 
                     'houseval17':'houseval', 'pcol17':'pcol'}, inplace=True)
nc_17.columns
# Out:
# Index(['Unnamed: 0', 'GEOID', 'tpop', 'pnhwhite', 'pnhasn', 'pnhblk', 'phisp',
#        'nhwhite', 'nhasn', 'nhblk',
#        ...
#        'Percent of Female Population 55 to 59',
#        'Percent of Female Population 60 to 61',
#        'Percent of Female Population 62 to 64',
#        'Percent of Female Population 65 to 66',
#        'Percent of Female Population 67 to 69',
#        'Percent of Female Population 70 to 74',
#        'Percent of Female Population 75 to 79',
#        'Percent of Female Population 80 to 85',
#        'Percent of Female Population Over 85', 'Year'],
#       dtype='object', length=111)

# %%
nc_16.rename(columns={'pnhwhite16':'pnhwhite', 'pnhasn16':'pnhasn', 'pnhblk16':'pnhblk', 'phisp16':'phisp', 'medinc16':'medinc', 'rent16':'rent', 
                     'houseval16':'houseval', 'pcol16':'pcol'}, inplace=True)
nc_16.columns
# Out:
# Index(['Unnamed: 0', 'GEOID', 'tpop', 'pnhwhite', 'pnhasn', 'pnhblk', 'phisp',
#        'nhwhite', 'nhasn', 'nhblk',
#        ...
#        'Percent of Female Population 55 to 59',
#        'Percent of Female Population 60 to 61',
#        'Percent of Female Population 62 to 64',
#        'Percent of Female Population 65 to 66',
#        'Percent of Female Population 67 to 69',
#        'Percent of Female Population 70 to 74',
#        'Percent of Female Population 75 to 79',
#        'Percent of Female Population 80 to 85',
#        'Percent of Female Population Over 85', 'Year'],
#       dtype='object', length=111)

# %%
nc_15.rename(columns={'pnhwhite15':'pnhwhite', 'pnhasn15':'pnhasn', 'pnhblk15':'pnhblk', 'phisp15':'phisp', 'medinc15':'medinc', 'rent15':'rent', 
                     'houseval15':'houseval', 'pcol15':'pcol'}, inplace=True)
nc_15.columns
# Out:
# Index(['Unnamed: 0', 'GEOID', 'tpop', 'pnhwhite', 'pnhasn', 'pnhblk', 'phisp',
#        'nhwhite', 'nhasn', 'nhblk',
#        ...
#        'Percent of Female Population 55 to 59',
#        'Percent of Female Population 60 to 61',
#        'Percent of Female Population 62 to 64',
#        'Percent of Female Population 65 to 66',
#        'Percent of Female Population 67 to 69',
#        'Percent of Female Population 70 to 74',
#        'Percent of Female Population 75 to 79',
#        'Percent of Female Population 80 to 85',
#        'Percent of Female Population Over 85', 'Year'],
#       dtype='object', length=111)

# %%
df = nc_19.append([nc_18, nc_17, nc_16, nc_15])

# %%
df.drop(columns=['tpopml', 'tpopmlt5', 'tpopml5to9',
       'tpopml10to14', 'tpopml15to17', 'tpopml18to19', 'tpopml20', 'tpopml21',
       'tpopml22to24', 'tpopml25to29', 'tpopml30to34', 'tpopml35to39',
       'tpopml40to44', 'tpopml45to49', 'tpopml50to54', 'tpopml55to59',
       'tpopml60to61', 'tpopml62to64', 'tpopml65to66', 'tpopml67to69',
       'tpopml70to74', 'tpopml75to79', 'tpopml80to85', 'tpopmlgt85', 'tpopfml',
       'tpopfmlt5', 'tpopfml5to9', 'tpopfml10to14', 'tpopfml15to17',
       'tpopfml18to19', 'tpopfml20', 'tpopfml21', 'tpopfml22to24',
       'tpopfml25to29', 'tpopfml30to34', 'tpopfml35to39', 'tpopfml40to44',
       'tpopfml45to49', 'tpopfml50to54', 'tpopfml55to59', 'tpopfml60to61',
       'tpopfml62to64', 'tpopfml65to66', 'tpopfml67to69', 'tpopfml70to74',
       'tpopfml75to79', 'tpopfml80to85', 'tpopfmlgt85'], inplace=True)
df.columns
# Out:
# Index(['Unnamed: 0', 'GEOID', 'tpop', 'pnhwhite', 'pnhasn', 'pnhblk', 'phisp',
#        'nhwhite', 'nhasn', 'nhblk', 'hisp', 'medinc', 'rent', 'houseval',
#        'pcol', 'tpop2', 'Percent of Total Population Male',
#        'Percent of Male Population Under 5',
#        'Percent of Male Population 5 to 9',
#        'Percent of Male Population 10 to 14',
#        'Percent of Male Population 15 to 17',
#        'Percent of Male Population 18 to 19', 'Percent of Male Population 20',
#        'Percent of Male Population 21', 'Percent of Male Population 25 to 29',
#        'Percent of Male Population 30 to 34',
#        'Percent of Male Population 35 to 39',
#        'Percent of Male Population 40 to 44',
#        'Percent of Male Population 45 to 49',
#        'Percent of Male Population 50 to 54',
#        'Percent of Male Population 55 to 59',
#        'Percent of Male Population 60 to 61',
#        'Percent of Male Population 62 to 64',
# ...

# %%
df.rename(columns={'tpop2':'Total Population'})
df.columns
# Out:
# Index(['Unnamed: 0', 'GEOID', 'tpop', 'pnhwhite', 'pnhasn', 'pnhblk', 'phisp',
#        'nhwhite', 'nhasn', 'nhblk', 'hisp', 'medinc', 'rent', 'houseval',
#        'pcol', 'tpop2', 'Percent of Total Population Male',
#        'Percent of Male Population Under 5',
#        'Percent of Male Population 5 to 9',
#        'Percent of Male Population 10 to 14',
#        'Percent of Male Population 15 to 17',
#        'Percent of Male Population 18 to 19', 'Percent of Male Population 20',
#        'Percent of Male Population 21', 'Percent of Male Population 25 to 29',
#        'Percent of Male Population 30 to 34',
#        'Percent of Male Population 35 to 39',
#        'Percent of Male Population 40 to 44',
#        'Percent of Male Population 45 to 49',
#        'Percent of Male Population 50 to 54',
#        'Percent of Male Population 55 to 59',
#        'Percent of Male Population 60 to 61',
#        'Percent of Male Population 62 to 64',
# ...

# %%
df.sort_values(by=['GEOID'], inplace=True)
df.head()
# Out:
#      Unnamed: 0        GEOID  tpop   pnhwhite    pnhasn     pnhblk     phisp  \
# 196         197  37051000200  2202   8.628520  1.589464  78.928247  8.673933
# 44           45  37051000200  2296  10.975610  2.526132  78.745645  5.879791
# 181         182  37051000200  2109  14.082504  1.896633  79.611190  2.939782
# 64           65  37051000200  2286   9.448819  1.443570  82.152231  5.424322
# 379         380  37051000200  2148  12.476723  2.467412  75.744879  7.029795
#
#      nhwhite  nhasn  nhblk  ...  Percent of Female Population 55 to 59  \
# 196      190     35   1738  ...                               0.041146
# 44       252     58   1808  ...                               0.048669
# 181      297     40   1679  ...                               0.061462
# 64       216     33   1878  ...                               0.046028
# 379      268     53   1627  ...                               0.056432
#
#      Percent of Female Population 60 to 61  \
# ...

# %%
# Out:
# <AxesSubplot:>
